# %% [markdown]
# <a href="https://colab.research.google.com/github/pvsas2003/Medi-assist/blob/main/Untitled7%20(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# =========================
# CONFIGURATION
# =========================
YEARS = 5 # Changed to 5 years to match the CSV data range
END_DATE = datetime(2018, 2, 7) # Set to the last date available in the CSV
START_DATE = END_DATE - timedelta(days=int(YEARS * 365))

US_TICKERS = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "META",
    "TSLA", "NVDA", "NFLX", "JPM", "AMD"
]

INDIA_TICKERS = [
    "RELIANCE.NS", "TCS.NS", "INFY.NS",
    "HDFCBANK.NS", "ICICIBANK.NS",
    "SBIN.NS", "ITC.NS",
    "LT.NS", "WIPRO.NS", "BHARTIARTL.NS"
]

# =========================
# LOAD US DATA (From CSV)
# =========================
def load_us_data(csv_path):
    df = pd.read_csv("/content/all_stocks_5yr.csv")

    # Ensure 'date' column exists, handling 'Date' if present
    if 'Date' in df.columns:
        df = df.rename(columns={'Date': 'date'})
    elif 'date' not in df.columns:
        print("Error: Neither 'Date' nor 'date' column found in CSV.")
        return pd.DataFrame() # Return empty DataFrame if no date column

    df['date'] = pd.to_datetime(df['date'])

    # Debugging prints
    print(f"--- Debugging load_us_data ---")
    print(f"Initial rows after date conversion: {len(df)}")
    print(f"Unique 'Name' values in raw data: {df['Name'].unique().tolist()}")
    print(f"Date range in raw data: {df['date'].min()} to {df['date'].max()}")
    print(f"Configured START_DATE: {START_DATE}")

    # Filter by US_TICKERS
    initial_rows = len(df)
    df = df[df['Name'].isin(US_TICKERS)]
    print(f"Rows after filtering by US_TICKERS ({len(US_TICKERS)} tickers): {len(df)}")
    if len(df) == 0:
        print("Warning: No data remaining after filtering by US_TICKERS. Check if ticker names in CSV match US_TICKERS.")
        # Identify which tickers are actually present in the dataframe
        all_tickers_in_csv = set(df['Name'].unique().tolist())
        present_tickers = all_tickers_in_csv.intersection(set(US_TICKERS))
        print(f"Tickers found in CSV that are also in US_TICKERS: {list(present_tickers)}")


    # Filter by date range
    initial_rows = len(df)
    df = df[df['date'] >= START_DATE]
    print(f"Rows after filtering by START_DATE ({START_DATE}): {len(df)}")
    if len(df) == 0 and initial_rows > 0: # Only warn if there was data before date filter
        print("Warning: No data remaining after filtering by START_DATE. Check date ranges.")

    print(f"Final DF shape in load_us_data: {df.shape}")
    print(f"--- End Debugging load_us_data ---")

    return df

# =========================
# LOAD INDIAN DATA (Yahoo)
# =========================
def load_india_data():
    data = yf.download(
        INDIA_TICKERS,
        start=START_DATE,
        end=END_DATE,
        group_by='ticker'
    )
    return data

# =========================
# TRANSFORM YFINANCE DATA
# =========================
def transform_yfinance_data(data):
    processed_dfs = []
    for ticker in INDIA_TICKERS:
        ticker_df = data[ticker].copy()
        ticker_df = ticker_df.reset_index()
        ticker_df['Name'] = ticker
        ticker_df.rename(columns={
            'Date': 'date',
            'Open': 'open',
            'High': 'high',
            'Low': 'low',
            'Close': 'close',
            'Volume': 'volume'
        }, inplace=True)
        processed_dfs.append(ticker_df)
    return pd.concat(processed_dfs, ignore_index=True)

# %%
india_df = load_india_data()
print(india_df.head())
# Out:
# /tmp/ipython-input-388/1576502384.py:74: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
# [*********************100%***********************]  10 of 10 completed
# Ticker           LT.NS                                               \
# Price             Open        High         Low       Close   Volume
# Date
# 2013-02-08  546.734726  560.274636  546.734726  554.477051  2011970
# 2013-02-11  555.504523  555.926498  545.267037  546.679749  1560595
# 2013-02-12  545.266912  551.504813  542.166304  548.569336  1741970
# 2013-02-13  547.285183  554.073456  542.331546  543.817627  1381088
# 2013-02-14  543.927535  546.367668  525.910993  528.791443  3035481
#
# Ticker     RELIANCE.NS                                                ...  \
# Price             Open        High         Low       Close    Volume  ...
# Date                                                                  ...
# ...

# %%
us_df = load_us_data("/content/all_stocks_5yr.csv")
print(us_df.head())
# Out:
# --- Debugging load_us_data ---
# Initial rows after date conversion: 619040
# ...

# %%
import pandas as pd
import numpy as np
from ta.momentum import RSIIndicator
from ta.trend import MACD, SMAIndicator
from sklearn.preprocessing import MinMaxScaler


# ==========================================
# ADD TECHNICAL INDICATORS (RSI, SMA, MACD)
# ==========================================
def add_indicators(df):

    df = df.copy()

    df['rsi'] = RSIIndicator(close=df['close'], window=14).rsi()
    df['sma'] = SMAIndicator(close=df['close'], window=14).sma_indicator()

    macd = MACD(close=df['close'])
    df['macd'] = macd.macd()

    df.dropna(inplace=True)

    return df


# ==========================================
# PROCESS MULTI-STOCK DATA
# ==========================================
def process_portfolio_data(df):

    stocks = df['Name'].unique()
    processed = []

    for stock in stocks:
        temp = df[df['Name'] == stock].sort_values('date')
        temp = add_indicators(temp)
        temp['Name'] = stock
        processed.append(temp)

    final_df = pd.concat(processed)

    return final_df


# ==========================================
# NORMALIZE FEATURES (SAFE VERSION)
# ==========================================
def normalize_features(df):

    df = df.copy()

    # 🔥 Preserve ORIGINAL close price for return calculation
    df['original_close'] = df['close']

    scaler = MinMaxScaler()

    feature_cols = ['close', 'volume', 'rsi', 'sma', 'macd']

    df[feature_cols] = scaler.fit_transform(df[feature_cols])

    return df, scaler


# ==========================================
# TRAIN-TEST SPLIT (70-30 BY DATE)
# ==========================================
def train_test_split(df):

    unique_dates = sorted(df['date'].unique())
    split_idx = int(len(unique_dates) * 0.7)

    train_dates = unique_dates[:split_idx]
    test_dates = unique_dates[split_idx:]

    train_df = df[df['date'].isin(train_dates)]
    test_df = df[df['date'].isin(test_dates)]

    return train_df, test_df

# %%
df = load_india_data()
df = transform_yfinance_data(df)

df = process_portfolio_data(df)

df, scaler = normalize_features(df)

train_df, test_df = train_test_split(df)
# Out:
# /tmp/ipython-input-388/3222417213.py:74: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
# [*********************100%***********************]  10 of 10 completed

# %%
us_df = load_us_data("/content/all_stocks_5yr.csv")

us_df = process_portfolio_data(us_df)
us_df, scaler = normalize_features(us_df)

train_df, test_df = train_test_split(us_df)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# --- Debugging load_us_data ---
# Initial rows after date conversion: 619040
# ...

# %%
import numpy as np

class PortfolioEnv:

    def __init__(self, df,
                 initial_capital=100000,
                 transaction_cost=0.001,
                 risk_lambda=0.1):

        self.df = df.copy()

        self.initial_capital = initial_capital
        self.transaction_cost = transaction_cost
        self.risk_lambda = risk_lambda

        self.stocks = sorted(self.df['Name'].unique())
        self.dates = sorted(self.df['date'].unique())

        self.n_stocks = len(self.stocks)

        self.reset()

    # =========================
    # RESET
    # =========================
    def reset(self):

        self.current_step = 0
        self.portfolio_value = self.initial_capital
        self.weights = np.ones(self.n_stocks) / self.n_stocks
        self.returns_history = []

        return self._get_state()

    # =========================
    # GET STATE (Normalized Features)
    # =========================
    def _get_state(self):

        date = self.dates[self.current_step]
        daily_data = self.df[self.df['date'] == date]

        state = []

        for stock in self.stocks:

            row = daily_data[daily_data['Name'] == stock]

            features = row[['close', 'volume', 'rsi', 'sma', 'macd']].values.flatten()

            state.extend(features)

        # Add normalized portfolio value
        state.append(self.portfolio_value / self.initial_capital)

        return np.array(state, dtype=np.float32)

    # =========================
    # STEP
    # =========================
    def step(self, action):

        done = False

        # Ensure positive weights and normalize
        action = np.maximum(action, 1e-8)
        new_weights = action / np.sum(action)

        prev_value = self.portfolio_value

        date_today = self.dates[self.current_step]
        date_next = self.dates[self.current_step + 1]

        today_data = self.df[self.df['date'] == date_today]
        next_data = self.df[self.df['date'] == date_next]

        daily_returns = []

        for stock in self.stocks:

            # 🔥 USE ORIGINAL CLOSE (NOT NORMALIZED)
            p_today = today_data[today_data['Name'] == stock]['original_close'].values[0]
            p_next = next_data[next_data['Name'] == stock]['original_close'].values[0]

            # Safe return calculation
            stock_return = (p_next - p_today) / (p_today + 1e-8)

            # Handle potential NaN or Inf returns defensively
            if np.isnan(stock_return) or np.isinf(stock_return):
                stock_return = 0.0

            daily_returns.append(stock_return)

        daily_returns = np.array(daily_returns)

        # Portfolio return
        portfolio_return = np.dot(new_weights, daily_returns)

        # Transaction cost
        turnover = np.sum(np.abs(new_weights - self.weights))
        cost = self.transaction_cost * turnover

        portfolio_return -= cost

        # Update portfolio value
        self.portfolio_value *= (1 + portfolio_return)

        self.weights = new_weights
        self.returns_history.append(portfolio_return)

        # Risk penalty (Sharpe-style)
        if len(self.returns_history) > 30:
            volatility = np.std(self.returns_history[-30:])
        else:
            volatility = np.std(self.returns_history)

        reward = portfolio_return - self.risk_lambda * volatility

        self.current_step += 1

        if self.current_step >= len(self.dates) - 1:
            done = True

        next_state = self._get_state()

        return next_state, reward, done, {}

# %%
env = PortfolioEnv(train_df)

state = env.reset()

print("State shape:", state.shape)

action = np.random.randn(env.n_stocks)
next_state, reward, done, _ = env.step(action)

print("Reward:", reward)
# Out:
# State shape: (41,)
# Reward: -0.004309278525319126

# %%
import numpy as np
import random
from collections import deque
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers

tf.config.optimizer.set_jit(True)

class DQNAgent:

    def __init__(self, state_size, action_size):

        self.state_size = state_size
        self.action_size = action_size

        self.memory = deque(maxlen=5000)

        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.batch_size = 64

        self.model = self._build_model()
        self.target_model = self._build_model()
        self.update_target_model()

    # =========================
    # BUILD NETWORK
    # =========================
    def _build_model(self):

        model = models.Sequential()
        model.add(layers.Dense(128, activation='relu', input_dim=self.state_size))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(32, activation='relu'))
        model.add(layers.Dense(self.action_size, activation='linear'))

        model.compile(
            loss='mse',
            optimizer=optimizers.Adam(learning_rate=self.learning_rate)
        )

        return model

    # =========================
    # TARGET UPDATE
    # =========================
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # =========================
    # STORE EXPERIENCE
    # =========================
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # =========================
    # ACTION SELECTION
    # =========================
    def act(self, state):

        if np.random.rand() <= self.epsilon:
            return np.random.randn(self.action_size)

        q_values = self.model.predict(state[np.newaxis], verbose=0)[0]
        return q_values

    # =========================
    # TRAINING STEP
    # =========================
    def replay(self):

        if len(self.memory) < self.batch_size:
            return

        minibatch = random.sample(self.memory, self.batch_size)

        states = []
        targets = []

        for state, action, reward, next_state, done in minibatch:

            target = self.model.predict(state[np.newaxis], verbose=0)[0]

            if done:
                target = reward
            else:
                t = self.target_model.predict(next_state[np.newaxis], verbose=0)[0]
                target = reward + self.gamma * np.max(t)

            states.append(state)
            targets.append(np.full(self.action_size, target))

        self.model.fit(
            np.array(states),
            np.array(targets),
            epochs=1,
            verbose=0
        )

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
import numpy as np

def train_dqn(train_df, episodes=10):

    env = PortfolioEnv(train_df)
    state_size = len(env.reset())
    action_size = env.n_stocks

    agent = DQNAgent(state_size, action_size)

    for e in range(episodes):

        state = env.reset()
        total_reward = 0
        step_count = 0

        while True:

            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)

            agent.remember(state, action, reward, next_state, done)

            state = next_state
            total_reward += reward
            step_count += 1

            if step_count % 20 == 0:
                agent.replay()

            if done:
                break

        # Train once more at episode end
        agent.replay()
        agent.update_target_model()

        print(f"Episode {e+1}/{episodes} | Reward: {total_reward:.4f}")

    agent.model.save("dqn_portfolio_model.h5")
    return agent

# %%
agent = train_dqn(train_df, episodes=10)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-388/254487781.py in <cell line: 0>()
# ----> 1 agent = train_dqn(train_df, episodes=10)
#
# /tmp/ipython-input-388/2823349546.py in train_dqn(train_df, episodes)
#      27
#      28             if step_count % 20 == 0:
# ---> 29                 agent.replay()
#      30
#      31             if done:
#
# /tmp/ipython-input-388/180374579.py in replay(self)
#      88                 target = reward
#      89             else:
# ...

# %%
def test_dqn(agent, test_df):

    env = PortfolioEnv(test_df)
    state = env.reset()

    portfolio_values = []

    while True:
        action = agent.model.predict(state[np.newaxis], verbose=0)[0]
        next_state, reward, done, _ = env.step(action)

        portfolio_values.append(env.portfolio_value)

        state = next_state

        if done:
            break

    return portfolio_values

# %%
import matplotlib.pyplot as plt


# ======================================
# Plot ALL Stocks Individually
# ======================================
def plot_all_stocks(df):

    stocks = sorted(df['Name'].unique())

    for stock in stocks:

        stock_df = df[df['Name'] == stock].sort_values("date")

        plt.figure()
        plt.plot(stock_df['date'], stock_df['original_close'])
        plt.title(f"{stock} Price Movement")
        plt.xlabel("Date")
        plt.ylabel("Close Price")
        plt.xticks(rotation=45)
        plt.show()

# %%
plot_all_stocks(df)

# %%
# ======================================
# Plot DQN Portfolio Value
# ======================================
def plot_portfolio(values, title="DQN Portfolio Value"):

    plt.figure()
    plt.plot(values)
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Portfolio Value")
    plt.show()

# %%
# ======================================
# Compare RL vs Equal Weight
# ======================================
def compare_rl_vs_traditional(rl_values, traditional_values):

    plt.figure()
    plt.plot(rl_values)
    plt.plot(traditional_values)
    plt.title("RL vs Traditional Strategy")
    plt.xlabel("Time")
    plt.ylabel("Portfolio Value")
    plt.legend(["DQN RL", "Equal Weight"])
    plt.show()

# %%
# Calculate DQN portfolio values
dqn_values = test_dqn(agent, test_df)

# Calculate Equal Weight portfolio values
env_equal_weight = PortfolioEnv(test_df) # Create a new environment for equal weight strategy
state_ew = env_equal_weight.reset()

equal_weight_values = [env_equal_weight.initial_capital] # Start with initial capital

while True:
    # Equal weights for all stocks
    action_ew = np.ones(env_equal_weight.n_stocks) / env_equal_weight.n_stocks
    _, _, done_ew, _ = env_equal_weight.step(action_ew)
    equal_weight_values.append(env_equal_weight.portfolio_value)
    if done_ew:
        break

compare_rl_vs_traditional(dqn_values, equal_weight_values)

# %%
# Traditional
traditional_values = equal_weight_values

# Compare
compare_rl_vs_traditional(dqn_values, traditional_values)

# %%
print(len(dqn_values))
# Out:
# 370

# %%
import matplotlib.pyplot as plt

def plot_portfolio(values, title="DQN Portfolio Value"):

    plt.figure(figsize=(8,5))
    plt.plot(values)
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Portfolio Value")
    plt.grid(True)
    plt.show()


def compare_rl_vs_traditional(rl_values, traditional_values):

    plt.figure(figsize=(8,5))
    plt.plot(rl_values)
    plt.plot(traditional_values)
    plt.title("RL vs Traditional Strategy")
    plt.xlabel("Time")
    plt.ylabel("Portfolio Value")
    plt.legend(["DQN RL", "Equal Weight"])
    plt.grid(True)
    plt.show()

# %%
print("RL length:", len(dqn_values))
print("Traditional length:", len(traditional_values))

plot_portfolio(dqn_values)

compare_rl_vs_traditional(dqn_values, traditional_values)
# Out:
# RL length: 370
# Traditional length: 371

# %%
portfolio_values = test_dqn(agent, test_df)

# %%
initial = portfolio_values[0]
final = portfolio_values[-1]

print("Initial Capital:", initial)
print("Final Capital:", final)
print("Total Return:", (final/initial - 1)*100, "%")
# Out:
# Initial Capital: 100795.16924329594
# Final Capital: 195022.1855732353
# Total Return: 93.48366299430224 %

# %%
import matplotlib.pyplot as plt

plt.plot(portfolio_values)
plt.title("DQN Portfolio Value")
plt.xlabel("Time")
plt.ylabel("Portfolio Value")
plt.show()

# %%
def test_dqn(agent, test_df):

    env = PortfolioEnv(test_df)
    state = env.reset()

    portfolio_values = []

    step = 0

    while True:
        action = agent.model.predict(state[np.newaxis], verbose=0)[0]
        next_state, reward, done, _ = env.step(action)

        portfolio_values.append(env.portfolio_value)

        print(f"Step {step} | Portfolio Value: {env.portfolio_value:.2f}")

        state = next_state
        step += 1

        if done:
            break

    return portfolio_values
